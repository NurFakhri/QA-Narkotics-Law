# %%
# !pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv

# %%
base_url = "https://putusan3.mahkamahagung.go.id/direktori/index/pengadilan/pn-sleman/kategori/narkotika-dan-psikotropika-1/tahunjenis/putus/tahun/2024/page/{page}.html" # Anda bisa menganti dengan link serupa

response = requests.get(base_url)

# Cek apakah permintaan berhasil dilakukan
if response.status_code == 200:
    html_content = response.text
else:
    print('Gagal mengambil halaman:', response.status_code)

# %%
# Inisialisasi halaman awal dan akhir
page_awal = 1
page_akhir = 5

# %%
# Loop untuk mengambil data hingga halaman 3
for page in range(page_awal, page_akhir):
    url = base_url.format(page=page)

    response = requests.get(url)

    if response.status_code == 200:
        # Parsing konten HTML
        soup = BeautifulSoup(response.text, 'html.parser')

        # Cari elemen <strong> yang memiliki <a> di dalamnya
        strong_tags = soup.find_all('strong')

        for strong in strong_tags:
            # Cari elemen <a> di dalam <strong>
            link = strong.find('a')
            if link:
                # Ambil teks dan href dari elemen <a>
                title = link.text.strip()
                href = link['href']

                print(f"Judul: {title}")
                print(f"URL: {href}\n")
    else:
        print(f"Gagal mengakses halaman {page}.")
# Out:
# Judul: Putusan PN SLEMAN Nomor 640/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbea8cef3a828bd76313530323530.html
#
# Judul: Putusan PN SLEMAN Nomor 641/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc5a53f0e3b691a5313633363031.html
#
# Judul: Putusan PN SLEMAN Nomor 545/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc5a2fffbfcc9f1f313633353031.html
#
# Judul: Putusan PN SLEMAN Nomor 586/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc5a1636124e8618313633343137.html
#
# Judul: Putusan PN SLEMAN Nomor 446/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc18ff15e7849bba303834313132.html
#
# Judul: Putusan PN SLEMAN Nomor 553/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb86a5bbcab46bae2313632303431.html
#
# Judul: Putusan PN SLEMAN Nomor 552/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb86a59be6c62a8bd313632303338.html
#
# Judul: Putusan PN SLEMAN Nomor 551/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb7a447be3fb8a34e313634323437.html
#
# Judul: Putusan PN SLEMAN Nomor 550/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb7a44133357ca6da313634323336.html
#
# Judul: Putusan PN SLEMAN Nomor 548/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb399d8b3cf24aac3313331383031.html
#
# Judul: Putusan PN SLEMAN Nomor 547/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb399d701f656a3a4313331373539.html
#
# Judul: Putusan PN SLEMAN Nomor 558/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb399ce4af012808a313331373434.html
#
# Judul: Putusan PN SLEMAN Nomor 549/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb399cb21e3a08eb7313331373339.html
#
# Judul: Putusan PN SLEMAN Nomor 566/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb399c96df0a89c5c313331373336.html
#
# Judul: Putusan PN SLEMAN Nomor 527/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb20846e29dc48705313332333239.html
#
# Judul: Putusan PN SLEMAN Nomor 568/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb20843e6bcf4acd2313332333234.html
#
# Judul: Putusan PN SLEMAN Nomor 529/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefae2420d3eab29016313433323436.html
#
# Judul: Putusan PN SLEMAN Nomor 474/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefab26ed1bb34eae80313931353134.html
#
# Judul: Putusan PN SLEMAN Nomor 515/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa8d51ff87b168631323032343338.html
#
# Judul: Putusan PN SLEMAN Nomor 494/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa6da48036820a932303735363331.html
#
# Judul: Putusan PN SLEMAN Nomor 463/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa6da408f485c88a7303735363138.html
#
# Judul: Putusan PN SLEMAN Nomor 528/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa6da34f8b924b29b303735353539.html
#
# Judul: Putusan PN SLEMAN Nomor 514/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa6da2e4d4cf2b07d303735353438.html
#
# Judul: Putusan PN SLEMAN Nomor 490/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa26858d98ea2b38d313631303532.html
#
# Judul: Putusan PN SLEMAN Nomor 454/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa0d7b7eaf850a887313632333033.html
#
# Judul: Putusan PN SLEMAN Nomor 493/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa
Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef6a9d8fc62842adf8313631303432.html
#
# Judul: Putusan PN SLEMAN Nomor 343/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef66b35e5ad142bdf9313633363433.html
#
# Judul: Putusan PN SLEMAN Nomor 312/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef65ac447a7d2aaab1303931333232.html
#
# Judul: Putusan PN SLEMAN Nomor 340/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef651c9e2edb26b943313630353035.html
#
# Judul: Putusan PN SLEMAN Nomor 344/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef5fbb7f760382b7c3313934373137.html
#
# Judul: Putusan PN SLEMAN Nomor 362/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef5fbb7c1bad90bef0313934373131.html
#
# Judul: Putusan PN SLEMAN Nomor 292/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef5dff964298f4855a313434393339.html
#
# Judul: Putusan PN SLEMAN Nomor 333/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef5aa9c7af6ac4bc84303835373531.html
#
# Judul: Putusan PN SLEMAN Nomor 277/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef5576a6c77e2eb1e5313830393136.html
#
# Judul: Putusan PN SLEMAN Nomor 325/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef5576a31493e881b4313830393130.html
#
# Judul: Putusan PN SLEMAN Nomor 278/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef55510132b534a436313333393437.html
#
# Judul: Putusan PN SLEMAN Nomor 252/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef54719a52eb5c85d6313130303336.html
#
# Judul: Putusan PN SLEMAN Nomor 212/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef4fe7460a6e6eb0a7313632303230.html
#
# Judul: Putusan PN SLEMAN Nomor 289/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef4e50bd7304c2bb14313535303135.html
#
# Judul: Putusan PN SLEMAN Nomor 240/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef4a41757f28988701313135303437.html
#
# Judul: Putusan PN SLEMAN Nomor 227/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef4a416ddac0ac983f313135303334.html
#
# Judul: Putusan PN SLEMAN Nomor 253/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef4a416c94984494fb313135303332.html
#
# Judul: Putusan PN SLEMAN Nomor 264/Pid.Sus/2024/PN Smn
# URL: https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef48ba4d5367368e9b313331303437.html

# %%
# Buka file CSV untuk menulis data
with open('putusan_links.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Putusan', 'Link'])

    # Loop untuk halaman
    for page in range(page_awal, page_akhir):
        url = base_url.format(page=page)
        response = requests.get(url)

        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            strong_tags = soup.find_all('strong')

            for strong in strong_tags:
                link = strong.find('a')
                if link:
                    title = link.text.strip()
                    href = link['href']
                    writer.writerow([title, href])

# %%
df = pd.read_csv('putusan_links.csv')
df.head()
# Out:
#                                            Putusan  \
# 0  Putusan PN SLEMAN Nomor 640/Pid.Sus/2024/PN Smn
# 1  Putusan PN SLEMAN Nomor 641/Pid.Sus/2024/PN Smn
# 2  Putusan PN SLEMAN Nomor 545/Pid.Sus/2024/PN Smn
# 3  Putusan PN SLEMAN Nomor 586/Pid.Sus/2024/PN Smn
# 4  Putusan PN SLEMAN Nomor 446/Pid.Sus/2024/PN Smn
#
#                                                 Link
# 0  https://putusan3.mahkamahagung.go.id/direktori...
# 1  https://putusan3.mahkamahagung.go.id/direktori...
# 2  https://putusan3.mahkamahagung.go.id/direktori...
# 3  https://putusan3.mahkamahagung.go.id/direktori...
# 4  https://putusan3.mahkamahagung.go.id/direktori...

# %%
# Baca semua link pada putusan_links.csv
link = df.drop(columns=['Putusan'])
link.head()
# Out:
#                                                 Link
# 0  https://putusan3.mahkamahagung.go.id/direktori...
# 1  https://putusan3.mahkamahagung.go.id/direktori...
# 2  https://putusan3.mahkamahagung.go.id/direktori...
# 3  https://putusan3.mahkamahagung.go.id/direktori...
# 4  https://putusan3.mahkamahagung.go.id/direktori...

# %%
# Siapkan file CSV untuk menyimpan data
with open('putusan_data.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)

    writer.writerow(["No Putusan", "Lembaga Peradilan", "Barang Bukti", "Amar Putusan"])

    # Loop melalui setiap URL dalam file CSV
    for url in link['Link']:
        response = requests.get(url)

        if response.status_code == 200:
            # Parsing konten HTML
            soup = BeautifulSoup(response.text, 'html.parser')

            # Cari tabel
            table = soup.find('table', {'class': 'table'})

            # Dictionary untuk menyimpan data
            data = {
                "No Putusan": None,
                "Lembaga Peradilan": None,
                "Barang Bukti": [],
                "Amar Putusan": []
            }

            if table:
                rows = table.find_all('tr')

                for row in rows:
                    cols = row.find_all('td')
                    if len(cols) == 2:
                        label = cols[0].text.strip()
                        value = cols[1].text.strip()

                        # Cocokkan label dengan key dictionary
                        if label == "Nomor":
                            data["No Putusan"] = value
                        elif label == "Lembaga Peradilan":
                            data["Lembaga Peradilan"] = value

                    # Cari dan ambil konten Barang Bukti
                    barang_bukti_ul = row.find('ul')
                    if barang_bukti_ul:
                        data["Barang Bukti"] = [li.text.strip() for li in barang_bukti_ul.find_all('li')]

                    # Jika Barang Bukti masih kosong, cari dengan teks
                    if not data["Barang Bukti"]:
                      if "Menetapkan barang bukti berupa" in row.text:
                        barang_bukti_start = row.text.split("Menetapkan barang bukti berupa")[1]

                        if "Dirampas" in barang_bukti_start:
                          barang_bukti_end = barang_bukti_start.split("Dirampas")[0]
                          data["Barang Bukti"] = [barang_bukti_end.strip()]

                        if "Dimusnahkan" in barang_bukti_start:
                          barang_bukti_end = barang_bukti_start.split("Dimusnahkan")[0]
                          data["Barang Bukti"] = [barang_bukti_end.strip()]

                        if "dirampas" in barang_bukti_start:
                          barang_bukti_end = barang_bukti_start.split("dirampas")[0]
                          data["Barang Bukti"] = [barang_bukti_end.strip()]

                        if "dimusnahkan" in barang_bukti_start:
                          barang_bukti_end = barang_bukti_start.split("dimusnahkan")[0]
                          data["Barang Bukti"] = [barang_bukti_end.strip()]

                    # Cari dan ambil konten Amar Putusan
                    amar_putusan_elements = row.find_all(['ol', 'ul', 'p'])
                    for element in amar_putusan_elements:
                        data["Amar Putusan"].append(element.text.strip())

            # Menulis data ke CSV
            writer.writerow([data["No Putusan"], data["Lembaga Peradilan"], "; ".join(data["Barang Bukti"]), "; ".join(data["Amar Putusan"])])
            print(f"Data untuk URL {url} berhasil disimpan.")
        else:
            print(f"Gagal mengakses halaman {url}.")
# Out:
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbea8cef3a828bd76313530323530.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc5a53f0e3b691a5313633363031.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc5a2fffbfcc9f1f313633353031.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc5a1636124e8618313633343137.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefbc18ff15e7849bba303834313132.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb86a5bbcab46bae2313632303431.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb86a59be6c62a8bd313632303338.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb7a447be3fb8a34e313634323437.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb7a44133357ca6da313634323336.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb399d8b3cf24aac3313331383031.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb399d701f656a3a4313331373539.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb399ce4af012808a313331373434.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb399cb21e3a08eb7313331373339.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb399c96df0a89c5c313331373336.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb20846e29dc48705313332333239.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefb20843e6bcf4acd2313332333234.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefae2420d3eab29016313433323436.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefab26ed1bb34eae80313931353134.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa8d51ff87b168631323032343338.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa6da48036820a932303735363331.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa6da408f485c88a7303735363138.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa6da34f8b924b29b303735353539.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa6da2e4d4cf2b07d303735353438.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa26858d98ea2b38d313631303532.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa0d7b7eaf850a887313632333033.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaefa0c39d18e532a358313335393038.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef972907ee2e7086a4303833393535.html berhasil disimpan.
# Data untuk URL https://putusan3.mahkamahagung.go.id/direktori/putusan/zaef